# %% [markdown]
# # **HackerRank Problems**

# %% [markdown]
# ## **If-Else**
# ![http://prntscr.com/sm28z1](attachment:image.png)

# %%
n = int(input())

if (n%2==0 and (2<n<=5 or n>20)):
    print("Not Weird")
else:
    print("Weird")
# Out:
#  3
# Weird
